# %%
# redirect_uri
#Client ID   5dc1ee52777082324f1f
#Client Secret   185e870663a96227ca9a490aa5b759c575d815e0
#code=66d3b9d14a4f18809d60

import requests
data={'client_id':'5dc1ee52777082324f1f','redirect_uri':'https://www.google.com/','login':'id',
      'scope':'user','state':'random_string'}
a=requests.get('https://github.com/login/oauth/authorize',params=data)
print(a)
print(a.url)
# Out:
# <Response [200]>
# https://github.com/login?client_id=5dc1ee52777082324f1f&login=varun29062000&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D5dc1ee52777082324f1f%26login%3Dvarun29062000%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26scope%3Duser%26state%3Drandom_string

# %%
data={'client_id':'5dc1ee52777082324f1f','client_secret':'185e870663a96227ca9a490aa5b759c575d815e0',
     'code':'66d3b9d14a4f18809d60','redirect_uri':'https://www.google.com/','state':'random_string'}
r=requests.post('https://github.com/login/oauth/access_token',params=data)
print(r.text)
# Out:
# access_token=5cdaa685adf02974be413ae33834ccea958dd594&scope=user&token_type=bearer

# %%
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594'}
d=requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',headers=h,params={'type':'all'})
d=d.json()
for i in d:
    if i['fork']==False:
        print(i['name'],i["watchers_count"],i["forks_count"],sep=' ')
# Out:
# SmoothScrollJs 16 5
# RubyTutorial 14 9
# Python3Tutorial 5 3
# HTMLandCssNotes 12 20
# Beacathon 2 8
# JSNotes 5 6
# learnml 1 0
# RubyNotebook 2 5
# InterQues 62 151
# coderoom 4 3
# ...

# %%
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594'}
d=requests.get('https://api.github.com/orgs/CodingNinjasCodes/members',headers=h,params={'type':'all'})
d=d.json()
for i in d:
    print(i['login'])
# Out:
# aakash-cr7
# dakshkhetan
# ManishaKhattar
# namangupta01
# nidhiagarwal
# rohanraarora

# %%
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594'}
d=requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/contributors',
               headers=h,params={'type':'all'})
d=d.json()

for i in range(3):
    print(d[i]['login'],)
#print(d[3]['name'])
# Out:
# Sherawat42
# Rawal27
# tushartuteja

# %%
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594'}
e=requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',
               headers=h,params={'type':'all','anon':'true'})
e=e.json()
for i in e:
    print(i['author']['login'],i['total'])
# Out:
# tushartuteja 5
# Rawal27 13
# Sherawat42 15

# %%
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594',
   'Accept':'application/vnd.github.black-panther-preview+json'}
e=requests.get('https://api.github.com/repos/CodingNinjasCodes/SmoothScrollJs/community/profile',
               headers=h,params={'type':'all','anon':'true'})
e=e.json()
print(e['health_percentage'])
# Out:
# 33

# %%
import requests
import json
h={'Authorization':'token 5cdaa685adf02974be413ae33834ccea958dd594',
   'Accept':'application/vnd.github.nebula-preview+json'}
a={'type':'all','direction':'desc'}
for i in range(10):
    b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'public','page':i})
    b=b.json()
    print(b[i]['name'])
# Out:
# x-mario
# phimpme-android
# susi_smart_box
# loklak_movietweets
# wp-dev-buddy
# susi_artwork
# yaydoc
# sciencetech.asia
# summit.fossasia.org
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-2477d67cec87> in <module>
#       7     b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'public','page':i})
#       8     b=b.json()
# ----> 9     print(b[i]['name'])
#
# IndexError: list index out of range

# %%
import requests
import json
h={'Accept':'application/vnd.github.nebula-preview+json'}
a={'type':'all','direction':'desc'}
for i in range(1,9):
    b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':8})
    b=b.json()
    for i in b:
        print(i['name'])
# Out:
# snowboy
# gci18.fossasia.org
# pi-gen
# jp.pslab.io
# in.pslab.io
# fossasia-jekyll-theme
# fossasia.sg
# pslab-iOS
# summit.fossasia.org
# photos.fossasia.org
# susi_installer
# susi_python
# susi_speech_server
# FOSSASIA-Office
# temp
# fossasia.tw
# orgmanager
# hyderabad.jugaadfest.com
# delhi.jugaadfest.com
# speech_recognition
# led-name-badge-ls32
# Event-Safety-Measures
# snowboy
# gci18.fossasia.org
# pi-gen
# jp.pslab.io
# in.pslab.io
# fossasia-jekyll-theme
# fossasia.sg
# pslab-iOS
# summit.fossasia.org
# photos.fossasia.org
# susi_installer
# susi_python
# susi_speech_server
# FOSSASIA-Office
# temp
# fossasia.tw
# orgmanager
# hyderabad.jugaadfest.com
# delhi.jugaadfest.com
# speech_recognition
# led-name-badge-ls32
# Event-Safety-Measures
# snowboy
# gci18.fossasia.org
# pi-gen
# jp.pslab.io
# in.pslab.io
# fossasia-jekyll-theme
# fossasia.sg
# pslab-iOS
# summit.fossasia.org
# photos.fossasia.org
# susi_installer
# susi_python
# susi_speech_server
# FOSSASIA-Office
# ...

# %%
import requests
import json
h={'Accept':'application/vnd.github.nebula-preview+json'}
a={'type':'all','direction':'desc'}
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':1})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':2})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':3})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':4})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':5})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':6})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':7})
b=b.json()
for i in b:
    print(i['name'])
b=requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,params={'type':'all','page':8})
b=b.json()
for i in b:
    print(i['name'])
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# knitlib
# pslab-expeyes
# timeline.api.fossasia.net
# 2016.fossasia.org
# fossasia.org
# pslab.io
# ...
